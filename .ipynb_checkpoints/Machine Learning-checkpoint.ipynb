# %%
import joblib
import time
import mysql.connector
from datetime import date
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.2)

# %%
df = pd.read_csv('olx_data_With_Final_Cleaning.csv')
df
# Out:
# C:\Users\Commandor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (8,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                      url  \
# 0      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 1      https://www.olx.com.eg/en/ad/%D8%B3%D9%83%D9%8...
# 2      https://www.olx.com.eg/en/ad/%D9%84%D9%82%D8%B...
# 3      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 4      https://www.olx.com.eg/en/ad/%D9%84%D8%B3%D8%B...
# ...                                                  ...
# 37704  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37705  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37706  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D9%8...
# 37707  https://www.olx.com.eg/en/ad/%D9%84%D9%84%D8%A...
# 37708  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
#
#                                                  title        date  \
# 0                   شقة للبيع بسكن مصر الاندلس مسلسل 1  2022-02-28
# 1        سكن مصر الأندلس مرحله ١ للبيع شقه دور اول ١١٥  2022-04-14
# 2               لقطه سكن مصر التجمع التالت افر 150 الف  2022-04-28
# 3      شقة للبيع بمدينة عمر بن الخطاب - آخر جسر السويس  2022-04-26
# 4                لسرعه البيع شقه سكن مصر التجمع التالت  2022-04-28
# ...                                                ...         ...
# 37704        شقة للبيع إمتداد مدينة 15 مايو مساحة 125م  2022-04-28
# 37705               شقة للبيع بكمبوند دار مصر دور ثالث  2022-04-28
# 37706                                        شقه للبيع  2022-02-28
# 37707                                            للبيع  2022-02-28
# 37708           شقة دور ارضي مرتفع سوبر لوكس مجاورة 15  2022-04-07
#
#                      location     compound       type   price  area bedrooms  \
# 0      New Cairo - El Tagamoa   Sakan Masr  Apartment  175000   115        3
# 1      New Cairo - El Tagamoa   Sakan Masr  Apartment  180000   115        3
# 2      New Cairo - El Tagamoa   Sakan Masr  Apartment  150000   115        3
# 3                Gesr Al Suez  no_compound  Apartment  450000   135        3
# 4      New Cairo - El Tagamoa   Sakan Masr  Apartment  160000   115        3
# ...                       ...          ...        ...     ...   ...      ...
# 37704             15 May City  no_compound  Apartment  550000   125        3
# 37705             15 May City     Dar Misr  Apartment  600000   140        3
# 37706             15 May City        Jewar  Apartment  470000    80        2
# 37707             15 May City  no_compound  Apartment  470000   100        2
# 37708             15 May City  no_compound  Apartment  440000   105        3
#
#         level  ... landline pets_allowed covered_parking private_garden pool  \
# 0           3  ...        1            1               1              1    0
# 1           1  ...        0            0               0              0    0
# 2           2  ...        0            0               0              0    0
# 3           7  ...        0            0               0              0    0
# 4           2  ...        0            0               0              0    0
# ...       ...  ...      ...          ...             ...            ...  ...
# 37704       2  ...        0            0               0              0    0
# 37705       3  ...        0            0               0              0    0
# 37706       5  ...        0            0               0              0    0
# 37707       4  ...        1            1               0              1    0
# 37708  Ground  ...        0            0               0              0    0
#
#       maids_room central_ac_heating built_in_kitchen_appliances  month  \
# 0              0                  0                           0      2
# 1              0                  0                           0      4
# 2              0                  0                           0      4
# 3              0                  0                           0      4
# 4              0                  0                           0      4
# ...          ...                ...                         ...    ...
# 37704          0                  0                           0      4
# 37705          0                  0                           0      4
# 37706          0                  0                           0      2
# 37707          0                  0                           0      2
# 37708          0                  0                           0      4
#
#        meterprice
# 0            1521
# 1            1565
# 2            1304
# 3            3333
# 4            1391
# ...           ...
# 37704        4400
# 37705        4285
# 37706        5875
# 37707        4700
# 37708        4190
#
# [37709 rows x 35 columns]

# %%
df['meterprice']=df['price']/df['area']

# %%
df[df['meterprice']]
# Out:
# count     37709.000000
# mean       9216.959440
# std        9091.484546
# min           0.385000
# 25%        4222.222222
# 50%        7700.000000
# 75%       12222.222222
# max      970588.235294
# Name: meterprice, dtype: float64

# %%
def nega(row):
    if row['down_payment'] < 0 :
        return 0
    else:
        return row['down_payment']

df['down_payment'] = df.apply(nega, axis=1)

# %%
df
# Out:
#                                                      url  \
# 0      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 1      https://www.olx.com.eg/en/ad/%D8%B3%D9%83%D9%8...
# 2      https://www.olx.com.eg/en/ad/%D9%84%D9%82%D8%B...
# 3      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 4      https://www.olx.com.eg/en/ad/%D9%84%D8%B3%D8%B...
# ...                                                  ...
# 37704  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37705  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37706  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D9%8...
# 37707  https://www.olx.com.eg/en/ad/%D9%84%D9%84%D8%A...
# 37708  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
#
#                                                  title        date  \
# 0                   شقة للبيع بسكن مصر الاندلس مسلسل 1  2022-02-28
# 1        سكن مصر الأندلس مرحله ١ للبيع شقه دور اول ١١٥  2022-04-14
# 2               لقطه سكن مصر التجمع التالت افر 150 الف  2022-04-28
# 3      شقة للبيع بمدينة عمر بن الخطاب - آخر جسر السويس  2022-04-26
# 4                لسرعه البيع شقه سكن مصر التجمع التالت  2022-04-28
# ...                                                ...         ...
# 37704        شقة للبيع إمتداد مدينة 15 مايو مساحة 125م  2022-04-28
# 37705               شقة للبيع بكمبوند دار مصر دور ثالث  2022-04-28
# 37706                                        شقه للبيع  2022-02-28
# 37707                                            للبيع  2022-02-28
# 37708           شقة دور ارضي مرتفع سوبر لوكس مجاورة 15  2022-04-07
#
#                      location     compound       type   price  area bedrooms  \
# 0      New Cairo - El Tagamoa   Sakan Masr  Apartment  175000   115        3
# 1      New Cairo - El Tagamoa   Sakan Masr  Apartment  180000   115        3
# 2      New Cairo - El Tagamoa   Sakan Masr  Apartment  150000   115        3
# 3                Gesr Al Suez  no_compound  Apartment  450000   135        3
# 4      New Cairo - El Tagamoa   Sakan Masr  Apartment  160000   115        3
# ...                       ...          ...        ...     ...   ...      ...
# 37704             15 May City  no_compound  Apartment  550000   125        3
# 37705             15 May City     Dar Misr  Apartment  600000   140        3
# 37706             15 May City        Jewar  Apartment  470000    80        2
# 37707             15 May City  no_compound  Apartment  470000   100        2
# 37708             15 May City  no_compound  Apartment  440000   105        3
#
#         level  ... landline pets_allowed covered_parking private_garden pool  \
# 0           3  ...        1            1               1              1    0
# 1           1  ...        0            0               0              0    0
# 2           2  ...        0            0               0              0    0
# 3           7  ...        0            0               0              0    0
# 4           2  ...        0            0               0              0    0
# ...       ...  ...      ...          ...             ...            ...  ...
# 37704       2  ...        0            0               0              0    0
# 37705       3  ...        0            0               0              0    0
# 37706       5  ...        0            0               0              0    0
# 37707       4  ...        1            1               0              1    0
# 37708  Ground  ...        0            0               0              0    0
#
#       maids_room central_ac_heating built_in_kitchen_appliances  month  \
# 0              0                  0                           0      2
# 1              0                  0                           0      4
# 2              0                  0                           0      4
# 3              0                  0                           0      4
# 4              0                  0                           0      4
# ...          ...                ...                         ...    ...
# 37704          0                  0                           0      4
# 37705          0                  0                           0      4
# 37706          0                  0                           0      2
# 37707          0                  0                           0      2
# 37708          0                  0                           0      4
#
#        meterprice
# 0            1521
# 1            1565
# 2            1304
# 3            3333
# 4            1391
# ...           ...
# 37704        4400
# 37705        4285
# 37706        5875
# 37707        4700
# 37708        4190
#
# [37709 rows x 35 columns]

# %%
df['furnished'].replace('No',0,inplace = True)
df['furnished'].replace('Yes',1,inplace = True)

# %%
df['furnished'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['delivery_date'].unique()
# Out:
# array(['Ready to move', 'soon', 'within 6 months', '2022', '2023', '2024',
#        '2026', '2025', '2030', '2027', '2028'], dtype=object)

# %%
df.columns
# Out:
# Index(['url', 'title', 'date', 'location', 'compound', 'type', 'price', 'area',
#        'bedrooms', 'level', 'furnished', 'price_type', 'bathrooms',
#        'payment_option', 'description', 'amenities', 'delivery_term',
#        'delivery_date', 'down_payment', 'electricity_meter', 'balcony',
#        'water_meter', 'elevator', 'security', 'natural_gas', 'landline',
#        'pets_allowed', 'covered_parking', 'private_garden', 'pool',
#        'maids_room', 'central_ac_heating', 'built_in_kitchen_appliances',
#        'month', 'meterprice'],
#       dtype='object')

# %%
df['meterprice']=df['price']/df['area']

# %%
df['meterprice'].describe()
# Out:
# count     37709.000000
# mean       9216.959440
# std        9091.484546
# min           0.385000
# 25%        4222.222222
# 50%        7700.000000
# 75%       12222.222222
# max      970588.235294
# Name: meterprice, dtype: float64

# %%
df = pd.get_dummies(df, columns=['delivery_term','location', 'compound', 'bedrooms', 'level','price_type','bathrooms','payment_option','delivery_date',], drop_first=True)
df
# Out:
#                                                      url  \
# 0      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 1      https://www.olx.com.eg/en/ad/%D8%B3%D9%83%D9%8...
# 2      https://www.olx.com.eg/en/ad/%D9%84%D9%82%D8%B...
# 3      https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 4      https://www.olx.com.eg/en/ad/%D9%84%D8%B3%D8%B...
# ...                                                  ...
# 37704  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37705  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
# 37706  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D9%8...
# 37707  https://www.olx.com.eg/en/ad/%D9%84%D9%84%D8%A...
# 37708  https://www.olx.com.eg/en/ad/%D8%B4%D9%82%D8%A...
#
#                                                  title        date       type  \
# 0                   شقة للبيع بسكن مصر الاندلس مسلسل 1  2022-02-28  Apartment
# 1        سكن مصر الأندلس مرحله ١ للبيع شقه دور اول ١١٥  2022-04-14  Apartment
# 2               لقطه سكن مصر التجمع التالت افر 150 الف  2022-04-28  Apartment
# 3      شقة للبيع بمدينة عمر بن الخطاب - آخر جسر السويس  2022-04-26  Apartment
# 4                لسرعه البيع شقه سكن مصر التجمع التالت  2022-04-28  Apartment
# ...                                                ...         ...        ...
# 37704        شقة للبيع إمتداد مدينة 15 مايو مساحة 125م  2022-04-28  Apartment
# 37705               شقة للبيع بكمبوند دار مصر دور ثالث  2022-04-28  Apartment
# 37706                                        شقه للبيع  2022-02-28  Apartment
# 37707                                            للبيع  2022-02-28  Apartment
# 37708           شقة دور ارضي مرتفع سوبر لوكس مجاورة 15  2022-04-07  Apartment
#
#         price  area  furnished  \
# 0      175000   115          0
# 1      180000   115          0
# 2      150000   115          0
# 3      450000   135          0
# 4      160000   115          0
# ...       ...   ...        ...
# 37704  550000   125          0
# 37705  600000   140          0
# 37706  470000    80          0
# 37707  470000   100          0
# 37708  440000   105          0
#
#                                              description  \
# 0      شقة لقطة للبيع بسكن مصر الاندلس دور متكرر فيو ...
# 1      للبيع دور اول\r\nفيو تحفه\r\nالأوفر ١٨٠ الف لس...
# 2      للبيت شقه سكن مصر التجمع التالت مسلسل 9\r\nمرح...
# 3      شقة عبارة عن نصف دور بها عدد 3 جهاز تكييف وسخا...
# 4      لقطه لسرعه البيع شقه سكن مصر التجمع التالت مسل...
# ...                                                  ...
# 37704  شقة  للبيع إمتداد مدينة 15 مايو مساحة 125م   \...
# 37705  شقة للبيع بكمبوند دار مصر 15 مايو دور ثالث بحر...
# 37706  شقه للبيع بارقي مكان بالإسكندرية أبراج رمادا ب...
# 37707  شقة للبيع بمدينة ١٥ مايو مجاورة ٥ \r\nقريبة من...
# 37708  شقة دور ارضي مرتفع 3 غرف وصالة \r\n2 حمام ومطب...
#
#                                                amenities  down_payment  ...  \
# 0      Landline; Natural Gas; Water Meter; Electricit...             0  ...
# 1      Natural Gas; Water Meter; Electricity Meter; S...             0  ...
# 2                                                    NaN             0  ...
# 3                         Elevator; Natural Gas; Balcony             0  ...
# 4                                                    NaN             0  ...
# ...                                                  ...           ...  ...
# 37704                                                NaN             0  ...
# 37705                                                NaN        600000  ...
# 37706  Elevator; Natural Gas; Water Meter; Electricit...             0  ...
# 37707  Landline; Water Meter; Electricity Meter; Pets...             0  ...
# 37708                                                NaN             0  ...
#
#        delivery_date_2023  delivery_date_2024  delivery_date_2025  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 37704                   0                   0                   0
# 37705                   0                   0                   0
# 37706                   0                   0                   0
# 37707                   0                   0                   0
# 37708                   0                   0                   0
#
#        delivery_date_2026  delivery_date_2027  delivery_date_2028  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 37704                   0                   0                   0
# 37705                   0                   0                   0
# 37706                   0                   0                   0
# 37707                   0                   0                   0
# 37708                   0                   0                   0
#
#        delivery_date_2030  delivery_date_Ready to move  delivery_date_soon  \
# 0                       0                            1                   0
# 1                       0                            1                   0
# 2                       0                            1                   0
# 3                       0                            1                   0
# 4                       0                            1                   0
# ...                   ...                          ...                 ...
# 37704                   0                            1                   0
# 37705                   0                            1                   0
# 37706                   0                            1                   0
# 37707                   0                            1                   0
# 37708                   0                            1                   0
#
#        delivery_date_within 6 months
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 37704                              0
# 37705                              0
# 37706                              0
# 37707                              0
# 37708                              0
#
# [37709 rows x 412 columns]

# %%
df.drop(['url','title','description','type','amenities','date'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['price', 'area', 'furnished', 'down_payment', 'electricity_meter',
#        'balcony', 'water_meter', 'elevator', 'security', 'natural_gas',
#        ...
#        'delivery_date_2023', 'delivery_date_2024', 'delivery_date_2025',
#        'delivery_date_2026', 'delivery_date_2027', 'delivery_date_2028',
#        'delivery_date_2030', 'delivery_date_Ready to move',
#        'delivery_date_soon', 'delivery_date_within 6 months'],
#       dtype='object', length=406)

# %%
x = df.drop('meterprice', axis=1)
y = df['meterprice']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_test
# Out:
#          price  area  furnished  down_payment  electricity_meter  balcony  \
# 757    1600000   140          0             0                  0        0
# 26820   250000    80          0             0                  0        1
# 25579   220000    80          0             0                  1        1
# 8665    510000   151          0             0                  0        1
# 33645   320000   110          0             0                  1        0
# ...        ...   ...        ...           ...                ...      ...
# 3712   1148000   162          0        150000                  1        1
# 18660  3500000   200          0             0                  0        0
# 25773   285000    75          0             0                  1        1
# 31202  2340000   140          0             0                  1        1
# 26617   870000   140          0        850000                  0        0
#
#        water_meter  elevator  security  natural_gas  ...  delivery_date_2023  \
# 757              0         0         0            0  ...                   0
# 26820            1         1         0            1  ...                   0
# 25579            1         0         0            1  ...                   0
# 8665             1         1         1            1  ...                   0
# 33645            0         1         0            1  ...                   0
# ...            ...       ...       ...          ...  ...                 ...
# 3712             1         1         1            1  ...                   1
# 18660            0         0         0            0  ...                   0
# 25773            1         0         0            1  ...                   0
# 31202            1         1         1            1  ...                   0
# 26617            0         1         1            1  ...                   0
#
#        delivery_date_2024  delivery_date_2025  delivery_date_2026  \
# 757                     0                   0                   0
# 26820                   0                   0                   0
# 25579                   0                   0                   0
# 8665                    0                   0                   0
# 33645                   0                   0                   0
# ...                   ...                 ...                 ...
# 3712                    0                   0                   0
# 18660                   0                   0                   0
# 25773                   0                   0                   0
# 31202                   0                   0                   0
# 26617                   0                   0                   0
#
#        delivery_date_2027  delivery_date_2028  delivery_date_2030  \
# 757                     0                   0                   0
# 26820                   0                   0                   0
# 25579                   0                   0                   0
# 8665                    0                   0                   0
# 33645                   0                   0                   0
# ...                   ...                 ...                 ...
# 3712                    0                   0                   0
# 18660                   0                   0                   0
# 25773                   0                   0                   0
# 31202                   0                   0                   0
# 26617                   0                   0                   0
#
#        delivery_date_Ready to move  delivery_date_soon  \
# 757                              1                   0
# 26820                            1                   0
# 25579                            1                   0
# 8665                             0                   1
# 33645                            0                   1
# ...                            ...                 ...
# 3712                             0                   0
# 18660                            1                   0
# 25773                            1                   0
# 31202                            1                   0
# 26617                            0                   0
#
#        delivery_date_within 6 months
# 757                                0
# 26820                              0
# 25579                              0
# 8665                               0
# 33645                              0
# ...                              ...
# 3712                               0
# 18660                              0
# 25773                              0
# 31202                              0
# 26617                              0
#
# [5657 rows x 405 columns]

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
models = {
    "LR": LinearRegression(),
    "KNNR" : KNeighborsRegressor(), 
    "SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
    "XGBR": XGBRegressor()
}

# %%
model = XGBRegressor()
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'MASE Score: {np.sqrt(mean_absolute_error(y_test, y_pred))}')  
    print(f'MSE Score: {np.sqrt(mean_squared_error(y_test, y_pred))}')  
    print(f'R2 Score: {r2_score(y_test, y_pred)}')
    print('-'*30)
# Out:
# Using model: LR
# MASE Score: 783349.0757441476
# MSE Score: 24086486129437.95
# R2 Score: -1.035760680049599e+19
# ------------------------------
# Using model: KNNR
# MASE Score: 49.271414631666005
# MSE Score: 5118.60157264396
# R2 Score: 0.5322485127615406
# ------------------------------
# Using model: SVR
# MASE Score: 68.4486805166331
# MSE Score: 7510.344730233382
# R2 Score: -0.007006489416597761
# ------------------------------
# Using model: DT
# MASE Score: 15.655688529990124
# MSE Score: 11119.694473024583
# R2 Score: -1.2074874071787862
# ------------------------------
# Using model: RF
# MASE Score: 10.21563200942327
# MSE Score: 3414.1402076176128
# R2 Score: 0.7918984907656333
# ------------------------------
# Using model: XGBR
# MASE Score: 11.864497155835744
# MSE Score: 720.7145477107164
# R2 Score: 0.990726597667021
# ------------------------------

# %%
df['meterprice'].describe()
# Out:
# count     37709.000000
# mean       9216.584211
# std        9091.470402
# min           0.000000
# 25%        4222.000000
# 50%        7700.000000
# 75%       12222.000000
# max      970588.000000
# Name: meterprice, dtype: float64

# %%
# y_pred = model.predict(x_test)
# np.sqrt(mean_squared_error(y_test, y_pred))

# %%
# r2_score(y_test, y_pred)

# %%
# from sklearn.feature_selection import RFE, SelectFromModel

# %%
# selector = RFE(model)
# selector.fit(x_train, y_train)

# %%
KNNR=KNeighborsRegressor()

# %%
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.metrics import accuracy_score

# %%
cv_results_KNNR = cross_validate(KNNR, x,y, cv=10, return_train_score=True, n_jobs=-1, scoring=('accuracy', 'precision', 'recall'))
cv_results_KNNR
# Out:
# {'fit_time': array([0.22686291, 0.25584292, 0.24285269, 0.26483774, 0.21786737,
#         0.25584316, 0.23585439, 0.22985983, 0.22986102, 0.25784349]),
#  'score_time': array([19.68526673, 22.05430627, 21.86442089, 22.33313417, 21.47766161,
#         21.90839624, 19.41509104, 19.75054598, 19.66659927, 21.63256431]),
#  'test_accuracy': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'train_accuracy': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'test_precision': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'train_precision': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'test_recall': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'train_recall': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])}

# %%
# from sklearn.pipeline import Pipeline
# from sklearn.decomposition import PCA
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier
# from xgboost import XGBClassifier
# from sklearn.svm import SVC

# bagged_svc = BaggingClassifier(base_estimator = SVC(kernel = 'rbf', C = 10, gamma = 100), n_estimators = 100)

# _pipeline = Pipeline(steps = [
#                               ('encoder', FunctionTransformer(encode)), 
#                               ('pca', PCA()), 
# #                               ('scaler', StandardScaler()), 
# #                               ('model', bagged_svc),])
# #                               ('model', SVC(kernel = 'rbf', C = 10, gamma = 100)),])
#                               ('model', RandomForestRegressor(n_estimators = 1000, n_jobs = 9, max_depth = 20, min_samples_leaf = 1, min_samples_split = 2, criterion = 'entropy', random_state = 42))])
# #                               ('model', LogisticRegression(C = 1.0, solver = 'saga', penalty = 'l2', max_iter = 1000, random_state = 42))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2bc0e4900f10> in <module>
#      10
#      11 _pipeline = Pipeline(steps = [
# ---> 12                               ('encoder', FunctionTransformer(encode)),
#      13                               ('pca', PCA()),
#      14 #                               ('scaler', StandardScaler()),
#
# NameError: name 'FunctionTransformer' is not defined

# %%
# from imblearn.pipeline import make_pipeline
# from imblearn.over_sampling import SMOTENC


# smotenc = SMOTENC(categorical_features = [0], k_neighbors = 5, random_state = 42)
# pipeline = make_pipeline(smotenc, _pipeline)
# pipeline
